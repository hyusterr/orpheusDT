# %% [markdown]
# # Functions demo for OrpheusDT

# %%
import pandas as pd
from orpheus import OrpheusDT
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# ## Data preprocessing

# %%
csv_name = './data/WFH_WFO_dataset.csv'
df = pd.read_csv(csv_name)
df.head()
# Out:
#    ID      Name  Age Occupation  Gender Same_ofiice_home_location kids  \
# 0   1   Bhavana   45      Tutor  Female                       Yes  Yes
# 1   2     Harry   24      Tutor    Male                        No   No
# 2   3  Banditaa   53         HR  Female                       Yes  Yes
# 3   4    Neetha   26   Engineer  Female                       Yes   No
# 4   5       Ram   26  Recruiter    Male                       Yes   No
#
#   RM_save_money RM_quality_time RM_better_sleep calmer_stressed  \
# 0           Yes             Yes             Yes          CALMER
# 1            No              No              No          CALMER
# 2           Yes             Yes             Yes          CALMER
# 3           Yes             Yes              No        STRESSED
# 4            No             Yes              No        STRESSED
#
#    RM_professional_growth  RM_lazy  RM_productive digital_connect_sufficient  \
# 0                       5        1              5                        Yes
# 1                       2        2              2                         No
# 2                       3        3              4                         No
# 3                       3        4              4                         No
# 4                       3        3              5                        Yes
#
#    RM_better_work_life_balance  RM_improved_skillset RM_job_opportunities  \
# 0                            5                     5                  Yes
# 1                            3                     3                   No
# 2                            5                     3                   No
# 3                            4                     5                  Yes
# 4                            4                     2                  Yes
#
#    Target
# 0       1
# 1       1
# 2       1
# 3       0
# 4       1

# %%
target = 'Target'
features_exclude = ['ID', 'Name']
features_yesno = [
    'Same_ofiice_home_location', 
    'kids',
    'RM_save_money',
    'RM_quality_time',
    'RM_better_sleep',
    'digital_connect_sufficient',
    'RM_job_opportunities'
]

# %%
df_train = pd.get_dummies(df[[i for i in df.columns if i not in features_exclude]].copy())

# %%
feature_names = [i for i in df_train.columns if i != target]
X = df_train[feature_names]
y = df_train[target]

# %% [markdown]
# ## Set up different versions of data

# %%
data_versions = {
    'version1': (X.iloc[:100].copy(), y.iloc[:100].copy()),
    'version2': (X.iloc[:120].copy(), y.iloc[:120].copy()),
    'version3': (X.iloc[:150].copy(), y.iloc[:150].copy()),
    'version4': (X.iloc[:180].copy(), y.iloc[:180].copy()),
    'version5': (X.copy(), y.copy()),
}

# %%
# from IPython.display import display
# for _, d in data_versions.items():
#     display(d[0].isna().sum())

# %% [markdown]
# ## Start OrpheusDT

# %% [markdown]
# ## Instance OrpheusDT with your task name and your name

# %%
orpheusDT = OrpheusDT(
    "WFH_WFO",
    "Alex"
)

# %% [markdown]
# ## There are 3 training modes
# ### 1. new data + new model
#      orpheus_instance.train(data_name, X, y, model_name, model)
#
# ### 2. new data + existed model
#      orpheus_instance.train(data_name, X, y, model_name)
#
# ### 3. existed data + new model
#      orpheus_instance.train(data_name, model_name, model)

# %% [markdown]
# ## 1. Training with new data + new model

# %%
# Data preparation
data_name = 'version3'
X = data_versions[data_name][0]
y = data_versions[data_name][1]
# Model preparation
model_name = "dfc_v1"
model = DecisionTreeClassifier()

# Train
orpheusDT.train(data_name, X, y, model_name, model)
# Out:
# [I 2022-06-05 09:56:36,274] A new study created in memory with name: no-name-398a2b0b-ea47-42a9-a17c-0fee0c5334a0
# [I 2022-06-05 09:56:36,629] Trial 0 finished with value: 0.8100000000000002 and parameters: {'criterion': 'gini', 'splitter': 'best', 'min_samples_split': 8, 'min_samples_leaf': 2, 'max_depth': 4}. Best is trial 0 with value: 0.8100000000000002.
# [I 2022-06-05 09:56:36,951] Trial 1 finished with value: 0.86 and parameters: {'criterion': 'gini', 'splitter': 'random', 'min_samples_split': 7, 'min_samples_leaf': 4, 'max_depth': 29}. Best is trial 1 with value: 0.86.
# [I 2022-06-05 09:56:37,188] Trial 2 finished with value: 0.8400000000000001 and parameters: {'criterion': 'entropy', 'splitter': 'random', 'min_samples_split': 6, 'min_samples_leaf': 2, 'max_depth': 4}. Best is trial 1 with value: 0.86.
# [I 2022-06-05 09:56:37,197] Trial 3 finished with value: 0.79 and parameters: {'criterion': 'gini', 'splitter': 'best', 'min_samples_split': 9, 'min_samples_leaf': 9, 'max_depth': 5}. Best is trial 1 with value: 0.86.
# [I 2022-06-05 09:56:37,206] Trial 4 finished with value: 0.8699999999999999 and parameters: {'criterion': 'gini', 'splitter': 'best', 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_depth': 28}. Best is trial 4 with value: 0.8699999999999999.
# [I 2022-06-05 09:56:37,216] Trial 5 finished with value: 0.8400000000000001 and parameters: {'criterion': 'gini', 'splitter': 'random', 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_depth': 3}. Best is trial 4 with value: 0.8699999999999999.
# [I 2022-06-05 09:56:37,225] Trial 6 finished with value: 0.8700000000000001 and parameters: {'criterion': 'entropy', 'splitter': 'random', 'min_samples_split': 9, 'min_samples_leaf': 10, 'max_depth': 3}. Best is trial 6 with value: 0.8700000000000001.
# [I 2022-06-05 09:56:37,236] Trial 7 finished with value: 0.8099999999999999 and parameters: {'criterion': 'gini', 'splitter': 'random', 'min_samples_split': 6, 'min_samples_leaf': 8, 'max_depth': 12}. Best is trial 6 with value: 0.8700000000000001.
# [I 2022-06-05 09:56:37,246] Trial 8 finished with value: 0.8800000000000001 and parameters: {'criterion': 'gini', 'splitter': 'best', 'min_samples_split': 6, 'min_samples_leaf': 4, 'max_depth': 4}. Best is trial 8 with value: 0.8800000000000001.
# [I 2022-06-05 09:56:37,258] Trial 9 finished with value: 0.7999999999999999 and parameters: {'criterion': 'entropy', 'splitter': 'random', 'min_samples_split': 10, 'min_samples_leaf': 8, 'max_depth': 19}. Best is trial 8 with value: 0.8800000000000001.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:56:37,272] Trial 10 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:56:37,286] Trial 11 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:56:37,300] Trial 12 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:56:37,314] Trial 13 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:56:37,328] Trial 14 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:56:37,342] Trial 15 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:56:37,355] Trial 16 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:56:37,369] Trial 17 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:56:37,383] Trial 18 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:56:37,396] Trial 19 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:56:37,409] Trial 20 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:56:37,425] Trial 21 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:56:37,438] Trial 22 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:56:37,452] Trial 23 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:56:37,466] Trial 24 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:56:37,480] Trial 25 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:56:37,494] Trial 26 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:56:37,508] Trial 27 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:56:37,522] Trial 28 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:56:37,536] Trial 29 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:56:37,550] Trial 30 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:56:37,563] Trial 31 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:56:37,576] Trial 32 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:56:37,589] Trial 33 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:56:37,601] Trial 34 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:56:37,615] Trial 35 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:56:37,629] Trial 36 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:56:37,643] Trial 37 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:56:37,656] Trial 38 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:56:37,670] Trial 39 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:56:37,683] Trial 40 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:56:37,695] Trial 41 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:56:37,708] Trial 42 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:56:37,721] Trial 43 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:56:37,735] Trial 44 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:56:37,749] Trial 45 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:56:37,762] Trial 46 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:56:37,775] Trial 47 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:56:37,789] Trial 48 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:56:37,802] Trial 49 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
# ...
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:56:38,423] Trial 87 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:56:38,438] Trial 88 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:56:38,454] Trial 89 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:56:38,469] Trial 90 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:56:38,483] Trial 91 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:56:38,503] Trial 92 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:56:38,521] Trial 93 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:56:38,536] Trial 94 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:56:38,551] Trial 95 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:56:38,567] Trial 96 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:56:38,583] Trial 97 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:56:38,597] Trial 98 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:56:38,613] Trial 99 failed, because the objective function returned nan.
# Training is done, evaluation score = 0.95
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1352/921241892.py in <module>
#       8
#       9 # Train
# ---> 10 orpheusDT.train(data_name, X, y, model_name, model)
#
# ~\anaconda3\lib\site-packages\multipledispatch\dispatcher.py in __call__(self, *args, **kwargs)
#     433             raise NotImplementedError('Could not find signature for %s: <%s>' %
#     434                                       (self.name, str_signature(types)))
# --> 435         return func(self.obj, *args, **kwargs)
#     436
#     437
#
# ~\Documents\Python\SQL-final\orpheusDT\src\orpheus\orpheus.py in train(self, data_name, data_x, data_y, model_name, model)
#      55
#      56         self.score, self.ct = self.fit()
# ---> 57         self.save_Data_to_DB()
#      58
#      59
#
# ~\anaconda3\lib\site-packages\multipledispatch\dispatcher.py in __call__(self, *args, **kwargs)
#     433             raise NotImplementedError('Could not find signature for %s: <%s>' %
#     434                                       (self.name, str_signature(types)))
# --> 435         return func(self.obj, *args, **kwargs)
#     436
#     437
#
# ~\Documents\Python\SQL-final\orpheusDT\src\orpheus\orpheus.py in save_Data_to_DB(self)
#     214     @dispatch(str, object, object)
#     215     def save_Data_to_DB(self, data_name, x, y):
# --> 216         """
#     217         Manually insert the data to DB when data_name not exist in DB
#     218         """
#
# Exception: Data named "version1" already exist, if you wish to use the existed "version1", please remove X and Y field

# %% [markdown]
# ## 2. Training with new data + existed model

# %%
# Data preparation
data_name = 'version5'
X = data_versions[data_name][0]
y = data_versions[data_name][1]
# Model preparation
model_name = "dfc_v1"
model = DecisionTreeClassifier()

# Train
orpheusDT.train(data_name, X, y, model_name)

# %% [markdown]
# ## 3. Training with existed data + new model

# %%
# Data preparation
data_name = 'version1'

# Model preparation
model_name = "dfc_v2"
model = DecisionTreeClassifier()

# Train
orpheusDT.train(data_name, model_name, model)

# %% [markdown]
# ## Show the difference of last and current training under specified data version
# orpheusDT.show_diff(data_name)

# %%
# Data preparation
data_name = 'version1'

# Model preparation
model_name = "dfc_v3"
model = DecisionTreeClassifier()

# Train
orpheusDT.train(data_name, model_name, model)

# show difference
orpheusDT.show_diff(data_name)

# %% [markdown]
# ## Based on one existing data, view all the model that had trained on it
# ## The model is ordered by evaluation score
# orpheusDT.view_all_model(data_name)

# %%
data_name = 'version1'
orpheusDT.view_all_model(data_name)

# %% [markdown]
# ## View all the data that saved in database
# orpheusDT.view_all_data()

# %%
orpheusDT.view_all_data()

# %% [markdown]
# ## Delete specified data or set data_name to "all" to delete all data
# orpheus_instance.delete_data(deleted_data_name)

# %%
deleted_data_name = 'version1'

orpheusDT.view_all_data()
orpheusDT.delete_data(deleted_data_name)
orpheusDT.view_all_data()

# %%
# new_row = {}
# for i in data_versions[data_name][0].columns:
#     print(i)
#     new_row[i] = int(input())

# %%
# new_row_pandas = pd.Series(new_row).to_frame().T

# %%
X = data_versions['version2'][0]
new_row_pandas = X.loc[0].to_frame().T

# %% [markdown]
# ## Fixed input, show different models' prediction
# orpheusDT.view_models_with_input(simple_row, model_list)

# %%
orpheusDT.view_models_with_input(new_row_pandas, ["dfc_v1", "dfc_v2"])

# %% [markdown]
# ## Manually Save data to database
# orpheusDT.save_Data_to_DB(data_name, X, y)

# %%
# Data preparation
data_name = 'version5'
X = data_versions[data_name][0]
y = data_versions[data_name][1]


orpheusDT.save_Data_to_DB(data_name, X, y)

# %% [markdown]
# ## Restore database by snapshot
# orpheusDT.restore_DB()

# %%
orpheusDT.restore_DB()

# %% [markdown]
# ## Reminder of possible incompatibility due to differnet sklearn version

# %%
# ! pip install scikit-learn==1.0.2
import sklearn
sklearn.__version__
# Out:
# '1.0.2'

# %%
# Data preparation
data_name = 'version1'

# Model preparation
model_name = "dfc_v2"

# Train
orpheusDT.train(data_name, model_name)
# Out:
# Data "version1" had been successfully extracted
# yaaaa The sklearn version of the loaded model is 1.1.1, while current environment has sklearn version 1.0.2, training result could be different
# Model "dfc_v2" had been successfully extracted
# [I 2022-06-05 09:58:17,222] A new study created in memory with name: no-name-9a49d02a-141c-43ce-84ac-3d267be6bb2b
# [I 2022-06-05 09:58:18,272] Trial 0 finished with value: 0.8200000000000001 and parameters: {'criterion': 'entropy', 'splitter': 'random', 'min_samples_split': 10, 'min_samples_leaf': 9, 'max_depth': 28}. Best is trial 0 with value: 0.8200000000000001.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:18,740] Trial 1 failed, because the objective function returned nan.
# [I 2022-06-05 09:58:19,068] Trial 2 finished with value: 0.8200000000000001 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'min_samples_split': 9, 'min_samples_leaf': 8, 'max_depth': 11}. Best is trial 0 with value: 0.8200000000000001.
# [I 2022-06-05 09:58:19,076] Trial 3 finished with value: 0.8300000000000001 and parameters: {'criterion': 'gini', 'splitter': 'best', 'min_samples_split': 2, 'min_samples_leaf': 7, 'max_depth': 6}. Best is trial 3 with value: 0.8300000000000001.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:19,084] Trial 4 failed, because the objective function returned nan.
# [I 2022-06-05 09:58:19,091] Trial 5 finished with value: 0.85 and parameters: {'criterion': 'gini', 'splitter': 'best', 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_depth': 12}. Best is trial 5 with value: 0.85.
# [I 2022-06-05 09:58:19,098] Trial 6 finished with value: 0.8099999999999999 and parameters: {'criterion': 'gini', 'splitter': 'random', 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_depth': 2}. Best is trial 5 with value: 0.85.
# [I 2022-06-05 09:58:19,104] Trial 7 finished with value: 0.89 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'min_samples_split': 7, 'min_samples_leaf': 6, 'max_depth': 14}. Best is trial 7 with value: 0.89.
# [I 2022-06-05 09:58:19,110] Trial 8 finished with value: 0.89 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'min_samples_split': 7, 'min_samples_leaf': 6, 'max_depth': 28}. Best is trial 7 with value: 0.89.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:19,116] Trial 9 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:19,122] Trial 10 failed, because the objective function returned nan.
# [I 2022-06-05 09:58:19,129] Trial 11 finished with value: 0.8300000000000001 and parameters: {'criterion': 'gini', 'splitter': 'best', 'min_samples_split': 10, 'min_samples_leaf': 7, 'max_depth': 5}. Best is trial 7 with value: 0.89.
# [I 2022-06-05 09:58:19,135] Trial 12 finished with value: 0.8 and parameters: {'criterion': 'gini', 'splitter': 'random', 'min_samples_split': 6, 'min_samples_leaf': 6, 'max_depth': 10}. Best is trial 7 with value: 0.89.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:19,141] Trial 13 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:19,148] Trial 14 failed, because the objective function returned nan.
# [I 2022-06-05 09:58:19,155] Trial 15 finished with value: 0.8300000000000001 and parameters: {'criterion': 'gini', 'splitter': 'best', 'min_samples_split': 2, 'min_samples_leaf': 10, 'max_depth': 7}. Best is trial 7 with value: 0.89.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:19,166] Trial 16 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:19,179] Trial 17 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:19,191] Trial 18 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:19,203] Trial 19 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:19,214] Trial 20 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:19,224] Trial 21 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:19,235] Trial 22 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:19,247] Trial 23 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:19,258] Trial 24 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:19,269] Trial 25 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:19,281] Trial 26 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:19,292] Trial 27 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:19,304] Trial 28 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:19,315] Trial 29 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:19,327] Trial 30 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:19,337] Trial 31 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:19,348] Trial 32 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:19,360] Trial 33 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:19,370] Trial 34 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:19,381] Trial 35 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:19,393] Trial 36 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:19,405] Trial 37 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:19,416] Trial 38 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:19,429] Trial 39 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:19,441] Trial 40 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:19,452] Trial 41 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:19,463] Trial 42 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:19,475] Trial 43 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:19,486] Trial 44 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:19,498] Trial 45 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:19,510] Trial 46 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:19,521] Trial 47 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:19,532] Trial 48 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:19,543] Trial 49 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
# ...
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:19,963] Trial 86 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:19,975] Trial 87 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:19,986] Trial 88 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:19,998] Trial 89 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:20,009] Trial 90 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:20,020] Trial 91 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:20,032] Trial 92 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:20,043] Trial 93 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:20,055] Trial 94 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:20,066] Trial 95 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:20,078] Trial 96 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:20,095] Trial 97 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:20,107] Trial 98 failed, because the objective function returned nan.
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 352, in fit
#     criterion = CRITERIA_CLF[self.criterion](
# KeyError: 'log_loss'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2022-06-05 09:58:20,118] Trial 99 failed, because the objective function returned nan.
# Training is done, evaluation score = 0.94
# Combination Data "version1" and Model "dfc_v2" already exist, with evaluation score = 0.97
# C:\Users\Romeo\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:103: FutureWarning: The attribute `n_features_` is deprecated in 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
## Inspect model by specifying
